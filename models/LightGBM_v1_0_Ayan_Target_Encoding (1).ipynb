# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score, classification_report

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install category_encoders

# %%
from category_encoders import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install lightgbm

# %%
import lightgbm as lgb

# %%
# Model and performance evaluation
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
lbl = preprocessing.LabelEncoder()
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import precision_recall_fscore_support as score
# Hyperparameter tuning
from sklearn.model_selection import StratifiedKFold, cross_val_score, GridSearchCV, RandomizedSearchCV
from hyperopt import tpe, STATUS_OK, Trials, hp, fmin, STATUS_OK, space_eval

# %%
pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %%
df = pd.read_csv("/content/drive/MyDrive/Crossroads/engg_data/crossroads_full_feature_set.csv")

# %%
df.isnull().sum()
# Out:
# acct_id                           0
# acct_type_desc                91418
# event_name                        0
# event_date                        0
# plan_event_name              279172
# comp_name                     80644
# section_name                      0
# row_name                          0
# SeatNum                           0
# price_code                        0
# PC1                               0
# Price                             0
# paid                         154145
# add_datetime                  80644
# class_name                        0
# status                            0
# Sales_Source                1280704
# isHost                            0
# SeatType                          0
# TicketClass                       0
# Start Year                  1146325
# LastYear                    1146325
# Term                        1146445
# TicketType                        0
# SeatUniqueID                      0
# Season                            0
# ClubExpYear                 1146325
# Tenure                        91418
# UniqueID                          0
# isAttended                        0
# Resold                      1140868
# ResalePrice                 1141991
# ResaleDate                  1140868
# isSTM                        900104
# acct_type_group               91418
# plan_event_name_group        279172
# row_name_group                    0
# seat_nums_group                   0
# section_names_group               0
# Zone                            480
# comp_names_group              80644
# price_group                       0
# PC1_group                         0
# class_name_grp                  434
# ticket_class_grp                  0
# TicketType_group                  0
# no_days_prebooked             80644
# gameday_minus_start_year    1146325
# lastyear_minus_gameday      1146325
# section_group                     0
# section_group_segment             0
# section_name_segment              0
# row_segment                       0
# seat_segment                      0
# Game_Type                         0
# Week                              0
# week_day                          0
# Game Time                         0
# Home Points                       0
# Away Points                       0
# unemployment_rate            128688
# covid_cases                       0
# Avg_Day_Temp                      0
# Precipitation                     0
# Avg_Dew_Point                     0
# weekend_flag                      0
# dtype: int64

# %%
def pivot(train_data, group_cols, agg_col):
    data = train_data.groupby(group_cols).agg({agg_col: "count"}).reset_index()
    data = pd.pivot_table(data, values=agg_col, index=[group_cols[0]], columns=[group_cols[1]], aggfunc=np.sum).reset_index().rename_axis(None, axis=1)
    data = data.fillna(0)
    data["count"] = data["Yes"] + data["No"]
    data["%Attended"] = 100*data["Yes"]/(data["Yes"]+data["No"])
    return data

# %%
accnt_type_df = pivot(df, ["acct_id", "isAttended"], "UniqueID")
accnt_type_df.head()
# Out:
#      acct_id     ???       No    Yes    count  %Attended
# 0        190  6467.0  68700.0  369.0  69069.0   0.534248
# 1   14999990     0.0      8.0    0.0      8.0   0.000000
# 2   16999990     0.0      1.0    0.0      1.0   0.000000
# 3  110002390    14.0     29.0   97.0    126.0  76.984127
# 4  110003490    20.0     25.0  135.0    160.0  84.375000

# %%
test_acct_ids = df[df["isAttended"]=="???"]["acct_id"].values

# %%
temp = df[df["isAttended"]!="???"]
acct_count_df = temp.groupby("acct_id").agg({"event_name": "nunique"}).reset_index()
acct_count_df = acct_count_df.rename(columns={"event_name": "event_name_count"})
acct_count_df.head()
# Out:
#      acct_id  event_name_count
# 0        190                18
# 1   14999990                 2
# 2   16999990                 1
# 3  110002390                18
# 4  110003490                16

# %%
"count", "%Attended", "event_name_count"
# Out:
# ('count', '%Attended', 'event_name_count')

# %%
df = df.merge(accnt_type_df[["acct_id", "count", "%Attended"]], on="acct_id", how="left")
df = df.merge(acct_count_df[["acct_id", "event_name_count"]], on="acct_id", how="left")

# %%
df.head()
# Out:
#       acct_id acct_type_desc event_name  event_date plan_event_name comp_name  \
# 0   117948790         Season   CLT21HOU  2021-10-17            21FS  Not Comp
# 1   126665090         Season   CLT21HOU  2021-10-17            21FS  Not Comp
# 2   126665090         Season   CLT21HOU  2021-10-17            21FS  Not Comp
# 3  1489599590         Season   CLT21HOU  2021-10-17            21FS  Not Comp
# 4   115101990         Season   CLT21HOU  2021-10-17            21FS  Not Comp
#
#    section_name row_name  SeatNum price_code PC1  Price paid  \
# 0           101       10        1         FR   F  111.0    Y
# 1           101       10       10         FR   F  111.0    Y
# 2           101       10       11         FR   F  111.0    Y
# 3           101       10       12         FR   F  111.0    Y
# 4           101       10       13         FR   F  111.0    Y
#
#           add_datetime class_name status  Sales_Source  isHost SeatType  \
# 0  2021-03-31 16:08:52       OPEN   SOLD           NaN       0       GA
# 1  2021-03-31 16:08:19       OPEN   SOLD           NaN       0       GA
# 2  2021-03-31 16:08:19       OPEN   SOLD           NaN       0       GA
# 3  2021-03-31 16:10:20       OPEN   SOLD           NaN       0       GA
# 4  2021-03-31 16:08:21       OPEN   SOLD           NaN       0       GA
#
#   TicketClass  Start Year  LastYear  Term TicketType SeatUniqueID  Season  \
# 0    Manifest         NaN       NaN   NaN    Renewal     101-10-1    2021
# 1    Manifest         NaN       NaN   NaN    Renewal    101-10-10    2021
# 2    Manifest         NaN       NaN   NaN    Renewal    101-10-11    2021
# 3    Manifest         NaN       NaN   NaN    Renewal    101-10-12    2021
# 4    Manifest         NaN       NaN   NaN    Renewal    101-10-13    2021
#
#    ClubExpYear  Tenure            UniqueID isAttended Resold  ResalePrice  \
# 0          NaN    25.0   CLT21HOU-101-10-1        Yes    NaN          NaN
# 1          NaN    20.0  CLT21HOU-101-10-10         No    NaN          NaN
# 2          NaN    20.0  CLT21HOU-101-10-11         No    NaN          NaN
# 3          NaN     4.0  CLT21HOU-101-10-12        Yes    NaN          NaN
# 4          NaN    32.0  CLT21HOU-101-10-13         No    NaN          NaN
#
#   ResaleDate  isSTM acct_type_group plan_event_name_group row_name_group  \
# 0        NaN    NaN              G1                    G1             G1
# 1        NaN    NaN              G1                    G1             G1
# 2        NaN    NaN              G1                    G1             G1
# 3        NaN    NaN              G1                    G1             G1
# 4        NaN    NaN              G1                    G1             G1
#
#   seat_nums_group section_names_group Zone comp_names_group    price_group  \
# 0              G1                  G1    N               G1  price_group_3
# 1              G1                  G1    N               G1  price_group_3
# 2              G1                  G1    N               G1  price_group_3
# 3              G1                  G1    N               G1  price_group_3
# 4              G1                  G1    N               G1  price_group_3
#
#      PC1_group class_name_grp ticket_class_grp TicketType_group  \
# 0  PC1_group_2   class_name_2   ticket_class_1          group_0
# 1  PC1_group_2   class_name_2   ticket_class_1          group_0
# 2  PC1_group_2   class_name_2   ticket_class_1          group_0
# 3  PC1_group_2   class_name_2   ticket_class_1          group_0
# 4  PC1_group_2   class_name_2   ticket_class_1          group_0
#
#    no_days_prebooked  gameday_minus_start_year  lastyear_minus_gameday  \
# 0              199.4                       NaN                     NaN
# 1              199.4                       NaN                     NaN
# 2              199.4                       NaN                     NaN
# 3              199.4                       NaN                     NaN
# 4              199.4                       NaN                     NaN
#
#    section_group section_group_segment section_name_segment row_segment  \
# 0            1.0                   Low                  Low         Low
# 1            1.0                   Low                  Low         Low
# 2            1.0                   Low                  Low         Low
# 3            1.0                   Low                  Low         Low
# 4            1.0                   Low                  Low         Low
#
#   seat_segment Game_Type  Week week_day Game Time  Home Points  Away Points  \
# 0          Low       Reg     6   Sunday     13:00          108           89
# 1          Low       Reg     6   Sunday     13:00          108           89
# 2          Low       Reg     6   Sunday     13:00          108           89
# 3          Low       Reg     6   Sunday     13:00          108           89
# 4          Low       Reg     6   Sunday     13:00          108           89
#
#    unemployment_rate  covid_cases  Avg_Day_Temp  Precipitation  Avg_Dew_Point  \
# 0                2.5        184.4         52.12            0.0          39.62
# 1                2.5        184.4         52.12            0.0          39.62
# 2                2.5        184.4         52.12            0.0          39.62
# 3                2.5        184.4         52.12            0.0          39.62
# 4                2.5        184.4         52.12            0.0          39.62
#
#    weekend_flag  count  %Attended  event_name_count
# 0             1   54.0  94.444444              18.0
# 1             1   72.0  70.833333              18.0
# 2             1   72.0  70.833333              18.0
# 3             1   18.0  83.333333              18.0
# 4             1  144.0  72.222222              18.0

# %%
df.isnull().sum()["%Attended"]
# Out:
# 13443

# %%
t0 = df[(df["isAttended"]=="???") & (df["%Attended"]<21) & (df["count"]>=10) & (df["event_name_count"]>2)]
t0.shape, t0.acct_id.nunique()
# Out:
# ((7128, 69), 96)

# %%
t = df[df["isAttended"]=="???"]
t.shape, t.acct_id.nunique()
# Out:
# ((128688, 69), 22102)

# %%
100.0*7128/128688
# Out:
# 5.538977993286087

# %%
att  = df["isAttended"].values
df = df.drop("isAttended", 1)
df["isAttended"] = att

# %%
df.head()
# Out:
#       acct_id acct_type_desc event_name  event_date plan_event_name comp_name  \
# 0   117948790         Season   CLT21HOU  2021-10-17            21FS  Not Comp
# 1   126665090         Season   CLT21HOU  2021-10-17            21FS  Not Comp
# 2   126665090         Season   CLT21HOU  2021-10-17            21FS  Not Comp
# 3  1489599590         Season   CLT21HOU  2021-10-17            21FS  Not Comp
# 4   115101990         Season   CLT21HOU  2021-10-17            21FS  Not Comp
#
#    section_name row_name  SeatNum price_code PC1  Price paid  \
# 0           101       10        1         FR   F  111.0    Y
# 1           101       10       10         FR   F  111.0    Y
# 2           101       10       11         FR   F  111.0    Y
# 3           101       10       12         FR   F  111.0    Y
# 4           101       10       13         FR   F  111.0    Y
#
#           add_datetime class_name status  Sales_Source  isHost SeatType  \
# 0  2021-03-31 16:08:52       OPEN   SOLD           NaN       0       GA
# 1  2021-03-31 16:08:19       OPEN   SOLD           NaN       0       GA
# 2  2021-03-31 16:08:19       OPEN   SOLD           NaN       0       GA
# 3  2021-03-31 16:10:20       OPEN   SOLD           NaN       0       GA
# 4  2021-03-31 16:08:21       OPEN   SOLD           NaN       0       GA
#
#   TicketClass  Start Year  LastYear  Term TicketType SeatUniqueID  Season  \
# 0    Manifest         NaN       NaN   NaN    Renewal     101-10-1    2021
# 1    Manifest         NaN       NaN   NaN    Renewal    101-10-10    2021
# 2    Manifest         NaN       NaN   NaN    Renewal    101-10-11    2021
# 3    Manifest         NaN       NaN   NaN    Renewal    101-10-12    2021
# 4    Manifest         NaN       NaN   NaN    Renewal    101-10-13    2021
#
#    ClubExpYear  Tenure            UniqueID Resold  ResalePrice ResaleDate  \
# 0          NaN    25.0   CLT21HOU-101-10-1    NaN          NaN        NaN
# 1          NaN    20.0  CLT21HOU-101-10-10    NaN          NaN        NaN
# 2          NaN    20.0  CLT21HOU-101-10-11    NaN          NaN        NaN
# 3          NaN     4.0  CLT21HOU-101-10-12    NaN          NaN        NaN
# 4          NaN    32.0  CLT21HOU-101-10-13    NaN          NaN        NaN
#
#    isSTM acct_type_group plan_event_name_group row_name_group seat_nums_group  \
# 0    NaN              G1                    G1             G1              G1
# 1    NaN              G1                    G1             G1              G1
# 2    NaN              G1                    G1             G1              G1
# 3    NaN              G1                    G1             G1              G1
# 4    NaN              G1                    G1             G1              G1
#
#   section_names_group Zone comp_names_group    price_group    PC1_group  \
# 0                  G1    N               G1  price_group_3  PC1_group_2
# 1                  G1    N               G1  price_group_3  PC1_group_2
# 2                  G1    N               G1  price_group_3  PC1_group_2
# 3                  G1    N               G1  price_group_3  PC1_group_2
# 4                  G1    N               G1  price_group_3  PC1_group_2
#
#   class_name_grp ticket_class_grp TicketType_group  no_days_prebooked  \
# 0   class_name_2   ticket_class_1          group_0              199.4
# 1   class_name_2   ticket_class_1          group_0              199.4
# 2   class_name_2   ticket_class_1          group_0              199.4
# 3   class_name_2   ticket_class_1          group_0              199.4
# 4   class_name_2   ticket_class_1          group_0              199.4
#
#    gameday_minus_start_year  lastyear_minus_gameday  section_group  \
# 0                       NaN                     NaN            1.0
# 1                       NaN                     NaN            1.0
# 2                       NaN                     NaN            1.0
# 3                       NaN                     NaN            1.0
# 4                       NaN                     NaN            1.0
#
#   section_group_segment section_name_segment row_segment seat_segment  \
# 0                   Low                  Low         Low          Low
# 1                   Low                  Low         Low          Low
# 2                   Low                  Low         Low          Low
# 3                   Low                  Low         Low          Low
# 4                   Low                  Low         Low          Low
#
#   Game_Type  Week week_day Game Time  Home Points  Away Points  \
# 0       Reg     6   Sunday     13:00          108           89
# 1       Reg     6   Sunday     13:00          108           89
# 2       Reg     6   Sunday     13:00          108           89
# 3       Reg     6   Sunday     13:00          108           89
# 4       Reg     6   Sunday     13:00          108           89
#
#    unemployment_rate  covid_cases  Avg_Day_Temp  Precipitation  Avg_Dew_Point  \
# 0                2.5        184.4         52.12            0.0          39.62
# 1                2.5        184.4         52.12            0.0          39.62
# 2                2.5        184.4         52.12            0.0          39.62
# 3                2.5        184.4         52.12            0.0          39.62
# 4                2.5        184.4         52.12            0.0          39.62
#
#    weekend_flag  count  %Attended  event_name_count isAttended
# 0             1   54.0  94.444444              18.0        Yes
# 1             1   72.0  70.833333              18.0         No
# 2             1   72.0  70.833333              18.0         No
# 3             1   18.0  83.333333              18.0        Yes
# 4             1  144.0  72.222222              18.0         No

# %%
df = df.drop(["acct_id", "event_date", "section_name", "row_name", "SeatNum", "Game Time", 
              "add_datetime", "Start Year", "LastYear", "SeatUniqueID", "ResaleDate", 
              "ClubExpYear"], 1)

# %%
df["Season"] = df["Season"].astype(str)

# %%
cat_cols = []
for k,v in dict(df.dtypes).items():
  if v=="object":
    cat_cols.append(k)

cat_cols = list(set(cat_cols) - set(["event_name", "UniqueID", "isAttended"]))

# %%
# cat_cols

# %%
from pandas.core.indexes import category
for col in cat_cols:
  df[col] = df[col].astype("category")

# %%
def label_encode(row, col):
  if row[col]=="Yes":
    return 1
  elif row[col]=="No":
    return 0
  else:
    return row[col]

df["isAttended"] = df.apply(lambda x: label_encode(x, "isAttended"), 1)

# %%
df.shape
# Out:
# (1286916, 57)

# %%
df.head()
# Out:
#   acct_type_desc event_name plan_event_name comp_name price_code PC1  Price  \
# 0         Season   CLT21HOU            21FS  Not Comp         FR   F  111.0
# 1         Season   CLT21HOU            21FS  Not Comp         FR   F  111.0
# 2         Season   CLT21HOU            21FS  Not Comp         FR   F  111.0
# 3         Season   CLT21HOU            21FS  Not Comp         FR   F  111.0
# 4         Season   CLT21HOU            21FS  Not Comp         FR   F  111.0
#
#   paid class_name status  Sales_Source  isHost SeatType TicketClass  Term  \
# 0    Y       OPEN   SOLD           NaN       0       GA    Manifest   NaN
# 1    Y       OPEN   SOLD           NaN       0       GA    Manifest   NaN
# 2    Y       OPEN   SOLD           NaN       0       GA    Manifest   NaN
# 3    Y       OPEN   SOLD           NaN       0       GA    Manifest   NaN
# 4    Y       OPEN   SOLD           NaN       0       GA    Manifest   NaN
#
#   TicketType Season  Tenure            UniqueID Resold  ResalePrice  isSTM  \
# 0    Renewal   2021    25.0   CLT21HOU-101-10-1    NaN          NaN    NaN
# 1    Renewal   2021    20.0  CLT21HOU-101-10-10    NaN          NaN    NaN
# 2    Renewal   2021    20.0  CLT21HOU-101-10-11    NaN          NaN    NaN
# 3    Renewal   2021     4.0  CLT21HOU-101-10-12    NaN          NaN    NaN
# 4    Renewal   2021    32.0  CLT21HOU-101-10-13    NaN          NaN    NaN
#
#   acct_type_group plan_event_name_group row_name_group seat_nums_group  \
# 0              G1                    G1             G1              G1
# 1              G1                    G1             G1              G1
# 2              G1                    G1             G1              G1
# 3              G1                    G1             G1              G1
# 4              G1                    G1             G1              G1
#
#   section_names_group Zone comp_names_group    price_group    PC1_group  \
# 0                  G1    N               G1  price_group_3  PC1_group_2
# 1                  G1    N               G1  price_group_3  PC1_group_2
# 2                  G1    N               G1  price_group_3  PC1_group_2
# 3                  G1    N               G1  price_group_3  PC1_group_2
# 4                  G1    N               G1  price_group_3  PC1_group_2
#
#   class_name_grp ticket_class_grp TicketType_group  no_days_prebooked  \
# 0   class_name_2   ticket_class_1          group_0              199.4
# 1   class_name_2   ticket_class_1          group_0              199.4
# 2   class_name_2   ticket_class_1          group_0              199.4
# 3   class_name_2   ticket_class_1          group_0              199.4
# 4   class_name_2   ticket_class_1          group_0              199.4
#
#    gameday_minus_start_year  lastyear_minus_gameday  section_group  \
# 0                       NaN                     NaN            1.0
# 1                       NaN                     NaN            1.0
# 2                       NaN                     NaN            1.0
# 3                       NaN                     NaN            1.0
# 4                       NaN                     NaN            1.0
#
#   section_group_segment section_name_segment row_segment seat_segment  \
# 0                   Low                  Low         Low          Low
# 1                   Low                  Low         Low          Low
# 2                   Low                  Low         Low          Low
# 3                   Low                  Low         Low          Low
# 4                   Low                  Low         Low          Low
#
#   Game_Type  Week week_day  Home Points  Away Points  unemployment_rate  \
# 0       Reg     6   Sunday          108           89                2.5
# 1       Reg     6   Sunday          108           89                2.5
# 2       Reg     6   Sunday          108           89                2.5
# 3       Reg     6   Sunday          108           89                2.5
# 4       Reg     6   Sunday          108           89                2.5
#
#    covid_cases  Avg_Day_Temp  Precipitation  Avg_Dew_Point  weekend_flag  \
# 0        184.4         52.12            0.0          39.62             1
# 1        184.4         52.12            0.0          39.62             1
# 2        184.4         52.12            0.0          39.62             1
# 3        184.4         52.12            0.0          39.62             1
# 4        184.4         52.12            0.0          39.62             1
#
#    count  %Attended  event_name_count isAttended
# 0   54.0  94.444444              18.0          1
# 1   72.0  70.833333              18.0          0
# 2   72.0  70.833333              18.0          0
# 3   18.0  83.333333              18.0          1
# 4  144.0  72.222222              18.0          0

# %%
train_df = df[(df["isAttended"]!="???") & (~df["event_name"].isin(["CLT22PIT", "CLT22LAC"]))]
val_df = df[(df["isAttended"]!="???") & (df["event_name"].isin(["CLT22PIT", "CLT22LAC"]))]
test_df = df[df["isAttended"]=="???"]

# %%
train_cnt = train_df["count"].values
train_att = train_df["%Attended"].values
train_event_cnt = train_df["event_name_count"].values

val_cnt = val_df["count"].values
val_att = val_df["%Attended"].values
val_event_cnt = val_df["event_name_count"].values

test_cnt = test_df["count"].values
test_att = test_df["%Attended"].values
test_event_cnt = test_df["event_name_count"].values

# %%
train_df = train_df.drop(["count", "%Attended", "event_name_count"], 1)
val_df = val_df.drop(["count", "%Attended", "event_name_count"], 1)
test_df = test_df.drop(["count", "%Attended", "event_name_count"], 1)

# %%
train_df.head()
# Out:
#   acct_type_desc event_name plan_event_name comp_name price_code PC1  Price  \
# 0         Season   CLT21HOU            21FS  Not Comp         FR   F  111.0
# 1         Season   CLT21HOU            21FS  Not Comp         FR   F  111.0
# 2         Season   CLT21HOU            21FS  Not Comp         FR   F  111.0
# 3         Season   CLT21HOU            21FS  Not Comp         FR   F  111.0
# 4         Season   CLT21HOU            21FS  Not Comp         FR   F  111.0
#
#   paid class_name status  Sales_Source  isHost SeatType TicketClass  Term  \
# 0    Y       OPEN   SOLD           NaN       0       GA    Manifest   NaN
# 1    Y       OPEN   SOLD           NaN       0       GA    Manifest   NaN
# 2    Y       OPEN   SOLD           NaN       0       GA    Manifest   NaN
# 3    Y       OPEN   SOLD           NaN       0       GA    Manifest   NaN
# 4    Y       OPEN   SOLD           NaN       0       GA    Manifest   NaN
#
#   TicketType Season  Tenure            UniqueID Resold  ResalePrice  isSTM  \
# 0    Renewal   2021    25.0   CLT21HOU-101-10-1    NaN          NaN    NaN
# 1    Renewal   2021    20.0  CLT21HOU-101-10-10    NaN          NaN    NaN
# 2    Renewal   2021    20.0  CLT21HOU-101-10-11    NaN          NaN    NaN
# 3    Renewal   2021     4.0  CLT21HOU-101-10-12    NaN          NaN    NaN
# 4    Renewal   2021    32.0  CLT21HOU-101-10-13    NaN          NaN    NaN
#
#   acct_type_group plan_event_name_group row_name_group seat_nums_group  \
# 0              G1                    G1             G1              G1
# 1              G1                    G1             G1              G1
# 2              G1                    G1             G1              G1
# 3              G1                    G1             G1              G1
# 4              G1                    G1             G1              G1
#
#   section_names_group Zone comp_names_group    price_group    PC1_group  \
# 0                  G1    N               G1  price_group_3  PC1_group_2
# 1                  G1    N               G1  price_group_3  PC1_group_2
# 2                  G1    N               G1  price_group_3  PC1_group_2
# 3                  G1    N               G1  price_group_3  PC1_group_2
# 4                  G1    N               G1  price_group_3  PC1_group_2
#
#   class_name_grp ticket_class_grp TicketType_group  no_days_prebooked  \
# 0   class_name_2   ticket_class_1          group_0              199.4
# 1   class_name_2   ticket_class_1          group_0              199.4
# 2   class_name_2   ticket_class_1          group_0              199.4
# 3   class_name_2   ticket_class_1          group_0              199.4
# 4   class_name_2   ticket_class_1          group_0              199.4
#
#    gameday_minus_start_year  lastyear_minus_gameday  section_group  \
# 0                       NaN                     NaN            1.0
# 1                       NaN                     NaN            1.0
# 2                       NaN                     NaN            1.0
# 3                       NaN                     NaN            1.0
# 4                       NaN                     NaN            1.0
#
#   section_group_segment section_name_segment row_segment seat_segment  \
# 0                   Low                  Low         Low          Low
# 1                   Low                  Low         Low          Low
# 2                   Low                  Low         Low          Low
# 3                   Low                  Low         Low          Low
# 4                   Low                  Low         Low          Low
#
#   Game_Type  Week week_day  Home Points  Away Points  unemployment_rate  \
# 0       Reg     6   Sunday          108           89                2.5
# 1       Reg     6   Sunday          108           89                2.5
# 2       Reg     6   Sunday          108           89                2.5
# 3       Reg     6   Sunday          108           89                2.5
# 4       Reg     6   Sunday          108           89                2.5
#
#    covid_cases  Avg_Day_Temp  Precipitation  Avg_Dew_Point  weekend_flag  \
# 0        184.4         52.12            0.0          39.62             1
# 1        184.4         52.12            0.0          39.62             1
# 2        184.4         52.12            0.0          39.62             1
# 3        184.4         52.12            0.0          39.62             1
# 4        184.4         52.12            0.0          39.62             1
#
#   isAttended
# 0          1
# 1          0
# 2          0
# 3          1
# 4          0

# %%
test_df.head()
# Out:
#        acct_type_desc event_name plan_event_name comp_name price_code PC1  \
# 193038         Season    CLT21LV            21FS  Not Comp         FR   F
# 193039         Season    CLT21LV            21FS  Not Comp         FR   F
# 193040         Season    CLT21LV            21FS  Not Comp         FR   F
# 193041         Season    CLT21LV            21FS  Not Comp         FR   F
# 193042         Season    CLT21LV            21FS  Not Comp         FR   F
#
#         Price paid class_name status  Sales_Source  isHost SeatType  \
# 193038  135.0    Y       OPEN   SOLD           NaN       0       GA
# 193039  135.0    Y       OPEN   SOLD           NaN       0       GA
# 193040  135.0    Y       OPEN   SOLD           NaN       0       GA
# 193041  135.0    Y       OPEN   SOLD           NaN       0       GA
# 193042  135.0    Y       OPEN   SOLD           NaN       0       GA
#
#        TicketClass  Term TicketType Season  Tenure           UniqueID Resold  \
# 193038    Manifest   NaN    Renewal   2021    25.0   CLT21LV-101-10-1    NaN
# 193039    Manifest   NaN    Renewal   2021    20.0  CLT21LV-101-10-10    NaN
# 193040    Manifest   NaN    Renewal   2021    20.0  CLT21LV-101-10-11    NaN
# 193041    Manifest   NaN    Renewal   2021     4.0  CLT21LV-101-10-12    NaN
# 193042    Manifest   NaN    Renewal   2021    32.0  CLT21LV-101-10-13    NaN
#
#         ResalePrice  isSTM acct_type_group plan_event_name_group  \
# 193038          NaN    NaN              G1                    G1
# 193039          NaN    NaN              G1                    G1
# 193040          NaN    NaN              G1                    G1
# 193041          NaN    NaN              G1                    G1
# 193042          NaN    NaN              G1                    G1
#
#        row_name_group seat_nums_group section_names_group Zone  \
# 193038             G1              G1                  G1    N
# 193039             G1              G1                  G1    N
# 193040             G1              G1                  G1    N
# 193041             G1              G1                  G1    N
# 193042             G1              G1                  G1    N
#
#        comp_names_group    price_group    PC1_group class_name_grp  \
# 193038               G1  price_group_3  PC1_group_2   class_name_2
# 193039               G1  price_group_3  PC1_group_2   class_name_2
# 193040               G1  price_group_3  PC1_group_2   class_name_2
# 193041               G1  price_group_3  PC1_group_2   class_name_2
# 193042               G1  price_group_3  PC1_group_2   class_name_2
#
#        ticket_class_grp TicketType_group  no_days_prebooked  \
# 193038   ticket_class_1          group_0              276.2
# 193039   ticket_class_1          group_0              276.2
# 193040   ticket_class_1          group_0              276.2
# 193041   ticket_class_1          group_0              276.2
# 193042   ticket_class_1          group_0              276.2
#
#         gameday_minus_start_year  lastyear_minus_gameday  section_group  \
# 193038                       NaN                     NaN            1.0
# 193039                       NaN                     NaN            1.0
# 193040                       NaN                     NaN            1.0
# 193041                       NaN                     NaN            1.0
# 193042                       NaN                     NaN            1.0
#
#        section_group_segment section_name_segment row_segment seat_segment  \
# 193038                  High                 High        High         High
# 193039                  High                 High        High         High
# 193040                  High                 High        High         High
# 193041                  High                 High        High         High
# 193042                  High                 High        High         High
#
#        Game_Type  Week week_day  Home Points  Away Points  unemployment_rate  \
# 193038       Reg    17   Sunday          420          316                2.2
# 193039       Reg    17   Sunday          420          316                2.2
# 193040       Reg    17   Sunday          420          316                2.2
# 193041       Reg    17   Sunday          420          316                2.2
# 193042       Reg    17   Sunday          420          316                2.2
#
#         covid_cases  Avg_Day_Temp  Precipitation  Avg_Dew_Point  weekend_flag  \
# 193038       1761.0         29.27            0.0          24.77             1
# 193039       1761.0         29.27            0.0          24.77             1
# 193040       1761.0         29.27            0.0          24.77             1
# 193041       1761.0         29.27            0.0          24.77             1
# 193042       1761.0         29.27            0.0          24.77             1
#
#        isAttended
# 193038        ???
# 193039        ???
# 193040        ???
# 193041        ???
# 193042        ???

# %%
test_df["isAttended"].unique()
# Out:
# array(['???'], dtype=object)

# %%
train_df.shape, val_df.shape, test_df.shape
# Out:
# ((1029536, 54), (128692, 54), (128688, 54))

# %%
train_df["event_name"].nunique(), val_df["event_name"].nunique(), test_df["event_name"].nunique()
# Out:
# (16, 2, 2)

# %%
X_train = train_df.iloc[:, :-1]
y_train = train_df.iloc[:, -1].values
X_val = val_df.iloc[:, :-1]
y_val = val_df.iloc[:, -1].values
X_test = test_df.iloc[:, :-1]
y_test = test_df.iloc[:, -1].values

# %%
enc = TargetEncoder(cols=cat_cols, min_samples_leaf=20, smoothing=10, handle_missing = 'return_nan').fit(X_train, y_train)
X_train_encoded = enc.transform(X_train)
X_val_encoded = enc.transform(X_val)
X_test_encoded = enc.transform(X_test)

# %%
X_train_encoded.head()
# Out:
#    acct_type_desc event_name  plan_event_name  comp_name  price_code  \
# 0        0.842318   CLT21HOU         0.831166   0.836616    0.850486
# 1        0.842318   CLT21HOU         0.831166   0.836616    0.850486
# 2        0.842318   CLT21HOU         0.831166   0.836616    0.850486
# 3        0.842318   CLT21HOU         0.831166   0.836616    0.850486
# 4        0.842318   CLT21HOU         0.831166   0.836616    0.850486
#
#         PC1  Price      paid  class_name    status  Sales_Source  isHost  \
# 0  0.840325  111.0  0.825416    0.823359  0.836616           NaN       0
# 1  0.840325  111.0  0.825416    0.823359  0.836616           NaN       0
# 2  0.840325  111.0  0.825416    0.823359  0.836616           NaN       0
# 3  0.840325  111.0  0.825416    0.823359  0.836616           NaN       0
# 4  0.840325  111.0  0.825416    0.823359  0.836616           NaN       0
#
#    SeatType  TicketClass  Term  TicketType    Season  Tenure  \
# 0  0.763649     0.791033   NaN     0.84441  0.752743    25.0
# 1  0.763649     0.791033   NaN     0.84441  0.752743    20.0
# 2  0.763649     0.791033   NaN     0.84441  0.752743    20.0
# 3  0.763649     0.791033   NaN     0.84441  0.752743     4.0
# 4  0.763649     0.791033   NaN     0.84441  0.752743    32.0
#
#              UniqueID  Resold  ResalePrice  isSTM  acct_type_group  \
# 0   CLT21HOU-101-10-1     NaN          NaN    NaN         0.840957
# 1  CLT21HOU-101-10-10     NaN          NaN    NaN         0.840957
# 2  CLT21HOU-101-10-11     NaN          NaN    NaN         0.840957
# 3  CLT21HOU-101-10-12     NaN          NaN    NaN         0.840957
# 4  CLT21HOU-101-10-13     NaN          NaN    NaN         0.840957
#
#    plan_event_name_group  row_name_group  seat_nums_group  \
# 0               0.828715        0.793333         0.775226
# 1               0.828715        0.793333         0.775226
# 2               0.828715        0.793333         0.775226
# 3               0.828715        0.793333         0.775226
# 4               0.828715        0.793333         0.775226
#
#    section_names_group      Zone  comp_names_group  price_group  PC1_group  \
# 0             0.808719  0.747116          0.834791     0.836764   0.827703
# 1             0.808719  0.747116          0.834791     0.836764   0.827703
# 2             0.808719  0.747116          0.834791     0.836764   0.827703
# 3             0.808719  0.747116          0.834791     0.836764   0.827703
# 4             0.808719  0.747116          0.834791     0.836764   0.827703
#
#    class_name_grp  ticket_class_grp  TicketType_group  no_days_prebooked  \
# 0         0.82742           0.78834          0.838018              199.4
# 1         0.82742           0.78834          0.838018              199.4
# 2         0.82742           0.78834          0.838018              199.4
# 3         0.82742           0.78834          0.838018              199.4
# 4         0.82742           0.78834          0.838018              199.4
#
#    gameday_minus_start_year  lastyear_minus_gameday  section_group  \
# 0                       NaN                     NaN            1.0
# 1                       NaN                     NaN            1.0
# 2                       NaN                     NaN            1.0
# 3                       NaN                     NaN            1.0
# 4                       NaN                     NaN            1.0
#
#    section_group_segment  section_name_segment  row_segment  seat_segment  \
# 0               0.671998              0.684329      0.67706      0.679989
# 1               0.671998              0.684329      0.67706      0.679989
# 2               0.671998              0.684329      0.67706      0.679989
# 3               0.671998              0.684329      0.67706      0.679989
# 4               0.671998              0.684329      0.67706      0.679989
#
#    Game_Type  Week  week_day  Home Points  Away Points  unemployment_rate  \
# 0   0.812634     6  0.782914          108           89                2.5
# 1   0.812634     6  0.782914          108           89                2.5
# 2   0.812634     6  0.782914          108           89                2.5
# 3   0.812634     6  0.782914          108           89                2.5
# 4   0.812634     6  0.782914          108           89                2.5
#
#    covid_cases  Avg_Day_Temp  Precipitation  Avg_Dew_Point  weekend_flag
# 0        184.4         52.12            0.0          39.62             1
# 1        184.4         52.12            0.0          39.62             1
# 2        184.4         52.12            0.0          39.62             1
# 3        184.4         52.12            0.0          39.62             1
# 4        184.4         52.12            0.0          39.62             1

# %%
train_ids = X_train["UniqueID"].values
val_ids = X_val["UniqueID"].values
test_ids = X_test["UniqueID"].values

X_train = X_train.drop(["UniqueID", "event_name"], 1)
X_val = X_val.drop(["UniqueID", "event_name"], 1)
X_test = X_test.drop(["UniqueID", "event_name"], 1)

# %%
train_ids = X_train_encoded["UniqueID"].values
val_ids = X_val_encoded["UniqueID"].values
test_ids = X_test_encoded["UniqueID"].values

X_train_encoded = X_train_encoded.drop(["UniqueID", "event_name"], 1)
X_val_encoded = X_val_encoded.drop(["UniqueID", "event_name"], 1)
X_test_encoded = X_test_encoded.drop(["UniqueID", "event_name"], 1)

# %%
X_train.head()
# Out:
#   acct_type_desc plan_event_name comp_name price_code PC1  Price paid  \
# 0         Season            21FS  Not Comp         FR   F  111.0    Y
# 1         Season            21FS  Not Comp         FR   F  111.0    Y
# 2         Season            21FS  Not Comp         FR   F  111.0    Y
# 3         Season            21FS  Not Comp         FR   F  111.0    Y
# 4         Season            21FS  Not Comp         FR   F  111.0    Y
#
#   class_name status  Sales_Source  isHost SeatType TicketClass  Term  \
# 0       OPEN   SOLD           NaN       0       GA    Manifest   NaN
# 1       OPEN   SOLD           NaN       0       GA    Manifest   NaN
# 2       OPEN   SOLD           NaN       0       GA    Manifest   NaN
# 3       OPEN   SOLD           NaN       0       GA    Manifest   NaN
# 4       OPEN   SOLD           NaN       0       GA    Manifest   NaN
#
#   TicketType Season  Tenure Resold  ResalePrice  isSTM acct_type_group  \
# 0    Renewal   2021    25.0    NaN          NaN    NaN              G1
# 1    Renewal   2021    20.0    NaN          NaN    NaN              G1
# 2    Renewal   2021    20.0    NaN          NaN    NaN              G1
# 3    Renewal   2021     4.0    NaN          NaN    NaN              G1
# 4    Renewal   2021    32.0    NaN          NaN    NaN              G1
#
#   plan_event_name_group row_name_group seat_nums_group section_names_group  \
# 0                    G1             G1              G1                  G1
# 1                    G1             G1              G1                  G1
# 2                    G1             G1              G1                  G1
# 3                    G1             G1              G1                  G1
# 4                    G1             G1              G1                  G1
#
#   Zone comp_names_group    price_group    PC1_group class_name_grp  \
# 0    N               G1  price_group_3  PC1_group_2   class_name_2
# 1    N               G1  price_group_3  PC1_group_2   class_name_2
# 2    N               G1  price_group_3  PC1_group_2   class_name_2
# 3    N               G1  price_group_3  PC1_group_2   class_name_2
# 4    N               G1  price_group_3  PC1_group_2   class_name_2
#
#   ticket_class_grp TicketType_group  no_days_prebooked  \
# 0   ticket_class_1          group_0              199.4
# 1   ticket_class_1          group_0              199.4
# 2   ticket_class_1          group_0              199.4
# 3   ticket_class_1          group_0              199.4
# 4   ticket_class_1          group_0              199.4
#
#    gameday_minus_start_year  lastyear_minus_gameday  section_group  \
# 0                       NaN                     NaN            1.0
# 1                       NaN                     NaN            1.0
# 2                       NaN                     NaN            1.0
# 3                       NaN                     NaN            1.0
# 4                       NaN                     NaN            1.0
#
#   section_group_segment section_name_segment row_segment seat_segment  \
# 0                   Low                  Low         Low          Low
# 1                   Low                  Low         Low          Low
# 2                   Low                  Low         Low          Low
# 3                   Low                  Low         Low          Low
# 4                   Low                  Low         Low          Low
#
#   Game_Type  Week week_day  Home Points  Away Points  unemployment_rate  \
# 0       Reg     6   Sunday          108           89                2.5
# 1       Reg     6   Sunday          108           89                2.5
# 2       Reg     6   Sunday          108           89                2.5
# 3       Reg     6   Sunday          108           89                2.5
# 4       Reg     6   Sunday          108           89                2.5
#
#    covid_cases  Avg_Day_Temp  Precipitation  Avg_Dew_Point  weekend_flag
# 0        184.4         52.12            0.0          39.62             1
# 1        184.4         52.12            0.0          39.62             1
# 2        184.4         52.12            0.0          39.62             1
# 3        184.4         52.12            0.0          39.62             1
# 4        184.4         52.12            0.0          39.62             1

# %%
y_train[:5]
# Out:
# array([1, 0, 0, 1, 0], dtype=object)

# %%
df["isAttended"].value_counts()
# Out:
# 1      900945
# 0      257283
# ???    128688
# Name: isAttended, dtype: int64

# %%
257283/900945, 900945/257283
# Out:
# (0.28557015134109187, 3.5017665372372058)

# %%
def learning_rate_010_decay_power_099(current_iter):
    base_learning_rate = 0.1
    lr = base_learning_rate  * np.power(.99, current_iter)
    return lr if lr > 1e-3 else 1e-3

def learning_rate_010_decay_power_0995(current_iter):
    base_learning_rate = 0.1
    lr = base_learning_rate  * np.power(.995, current_iter)
    return lr if lr > 1e-3 else 1e-3

def learning_rate_005_decay_power_099(current_iter):
    base_learning_rate = 0.05
    lr = base_learning_rate  * np.power(.99, current_iter)
    return lr if lr > 1e-3 else 1e-3

# %%
n_HP_points_to_test = 100

# %%
fit_params={"early_stopping_rounds":30, 
            "eval_metric" : 'auc', 
            "eval_set" : [(X_val_encoded,[int(each) for each in y_val])],
            'eval_names': ['valid'],
            #'callbacks': [lgb.reset_parameter(learning_rate=learning_rate_010_decay_power_099)],
            'verbose': 100,
            'categorical_feature': 'auto'}

# %%
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform
param_test ={'num_leaves': sp_randint(6, 50), 
             'min_child_samples': sp_randint(100, 500), 
             'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
             'subsample': sp_uniform(loc=0.2, scale=0.8), 
             'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
             'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
             'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]}

# %%
clf = lgb.LGBMClassifier(max_depth=-1, random_state=314, silent=True, metric='None', n_jobs=4, n_estimators=5000)
gs = RandomizedSearchCV(
    estimator=clf, param_distributions=param_test, 
    n_iter=n_HP_points_to_test,
    scoring='roc_auc',
    cv=3,
    refit=True,
    random_state=314,
    verbose=True)

# %%
# gs.fit(X_train_encoded, [int(each) for each in y_train], **fit_params)
# print('Best score reached: {} with params: {} '.format(gs.best_score_, gs.best_params_))

# %%
get_params_ = {'boosting_type': 'gbdt',
 'class_weight': None,
 'colsample_bytree': 1.0,
 'importance_type': 'split',
 'learning_rate': 0.1,
 'max_depth': -1,
 'min_child_samples': 20,
 'min_child_weight': 0.001,
 'min_split_gain': 0.0,
 'n_estimators': 5000,
 'n_jobs': 4,
 'num_leaves': 31,
 'objective': None,
 'random_state': 314,
 'reg_alpha': 0.0,
 'reg_lambda': 0.0,
 'silent': True,
 'subsample': 1.0,
 'subsample_for_bin': 200000,
 'subsample_freq': 0,
 'metric': 'None'}

# %%
opt_parameters = {'colsample_bytree': 0.7792703648870174, 'min_child_samples': 344, 'min_child_weight': 0.01, 
                  'num_leaves': 10, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 0.8503048560728566}

# %%
clf_sw = lgb.LGBMClassifier(**get_params_)
#set optimal parameters
clf_sw.set_params(**opt_parameters)
# Out:
# LGBMClassifier(colsample_bytree=0.7792703648870174, metric='None',
#                min_child_samples=344, min_child_weight=0.01, n_estimators=5000,
#                n_jobs=4, num_leaves=10, random_state=314, reg_alpha=0,
#                reg_lambda=10, silent=True, subsample=0.8503048560728566)

# %%
gs_sample_weight = GridSearchCV(estimator=clf_sw, 
                                param_grid={'scale_pos_weight':[1,2,6,12]},
                                scoring='roc_auc',
                                cv=5,
                                refit=True,
                                verbose=True)

# %%
gs_sample_weight.fit(X_train_encoded, [int(each) for each in y_train], **fit_params)
print('Best score reached: {} with params: {} '.format(gs_sample_weight.best_score_, gs_sample_weight.best_params_))
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [100]	valid's auc: 0.701978
# Best score reached: 0.7105866222835976 with params: {'scale_pos_weight': 12}

# %%
# print("Valid+-Std     Train  :   Parameters")
# for i in np.argsort(gs_sample_weight.cv_results_['mean_test_score'])[-5:]:
#     print('{1:.3f}+-{3:.3f}     :  {0}'.format(gs_sample_weight.cv_results_['params'][i], 
#                                     gs_sample_weight.cv_results_['mean_test_score'][i], 
#                                     gs_sample_weight.cv_results_['std_test_score'][i]))

# %%
print('Best score reached: {} with params: {} '.format(gs_sample_weight.best_score_, gs_sample_weight.best_params_))

# %%
# opt_sw_params = gs_sample_weight.best_params_

# %%
# clf_final = lgb.LGBMClassifier(**clf.get_params())
clf_final = lgb.LGBMClassifier(**get_params_)
#set optimal parameters
# clf_final.set_params(**opt_sw_params)

#Train the final model with learning rate decay
clf_final.fit(X_train_encoded, [int(each) for each in y_train], **fit_params, callbacks=[lgb.reset_parameter(learning_rate=learning_rate_010_decay_power_0995)])
# Out:
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [28]	valid's auc: 0.698464
# LGBMClassifier(metric='None', n_estimators=5000, n_jobs=4, random_state=314)

# %%
threshold=0.5

# %%
y_pred_val = clf_final.predict_proba(X_val_encoded)

# %%
y_pred_val = [1 if each[1]>threshold else 0 for each in y_pred_val]

print(classification_report([int(each) for each in y_val.tolist()], y_pred_val))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.22      0.36     19583
#            1       0.88      1.00      0.93    109109
#
#     accuracy                           0.88    128692
#    macro avg       0.94      0.61      0.64    128692
# weighted avg       0.90      0.88      0.85    128692

# %%
len(y_pred_val) - sum(y_pred_val), len(y_pred_val)
# Out:
# (4238, 128692)

# %%
# import sklearn
# sklearn.metrics.SCORERS.keys()

# %%
y_pred_val = [each[1] for each in clf_final.predict_proba(X_val_encoded)]

# %%
y_pred_val = [1 if each>threshold else 0 for each in y_pred_val]

# %%
print(classification_report([int(each) for each in y_val.tolist()], y_pred_val))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.22      0.36     19583
#            1       0.88      1.00      0.93    109109
#
#     accuracy                           0.88    128692
#    macro avg       0.94      0.61      0.64    128692
# weighted avg       0.90      0.88      0.85    128692

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix([int(each) for each in y_val.tolist()], y_pred_val))
# Out:
# [[  4235  15348]
#  [     3 109106]]

# %%
def get_heuristic_pred(row):
  if ((row['%Attended']<35) & (row['count']>=10) & (row["event_name_count"]>2)) or \
  (row["class_name"] in ['DIST-7HOLD','DIST-EXCP','DIST-WIP','KILL SEATS','OB2','OWNERSHIP','SINGLE GAME SRO','XTEST', 'UNTOUCHABLE','OBSTRUCTED']):
    return 0
  else:
    return row['model_pred']

# %%
val_pred_df = pd.DataFrame()
val_pred_df["UniqueID"] = val_ids
val_pred_df["count"] = val_cnt
val_pred_df["%Attended"] = val_att
val_pred_df["event_name_count"] = val_event_cnt
val_pred_df["class_name"] = val_df["class_name"].values
val_pred_df["TicketClass"] = val_df["TicketClass"].values
val_pred_df["Actual"] = [int(each) for each in y_val.tolist()]
val_pred_df["model_pred"] = y_pred_val
val_pred_df["heuristic_preds"] = val_pred_df.apply(lambda x: get_heuristic_pred(x), 1)

# %%
print(classification_report([int(each) for each in y_val.tolist()], val_pred_df["heuristic_preds"].values.tolist()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.26      0.40     19583
#            1       0.88      1.00      0.94    109109
#
#     accuracy                           0.88    128692
#    macro avg       0.90      0.63      0.67    128692
# weighted avg       0.89      0.88      0.85    128692

# %%
test_preds = [each[1] for each in clf_final.predict_proba(X_test_encoded)]

# %%
test_preds = [1 if each>threshold else 0 for each in test_preds]

# %%
1 - (sum(test_preds)/len(test_preds))
# Out:
# 0.05363359442993909

# %%
len(test_preds) - sum(test_preds), len(test_preds)
# Out:
# (6902, 128688)

# %%
len(test_acct_ids)
# Out:
# 128688

# %%
test_pred_df = pd.DataFrame()
test_pred_df["UniqueID"] = test_ids
test_pred_df["acct_id"] = test_acct_ids
test_pred_df["count"] = test_cnt
test_pred_df["%Attended"] = test_att
test_pred_df["event_name_count"] = test_event_cnt
test_pred_df["class_name"] = test_df["class_name"].values
test_pred_df["TicketClass"] = test_df["TicketClass"].values
test_pred_df["model_pred"] = test_preds
test_pred_df["heuristic_preds"] = test_pred_df.apply(lambda x: get_heuristic_pred(x), 1)

# %%
test_preds_heur = test_pred_df["heuristic_preds"].values
len(test_preds_heur) - sum(test_preds_heur), len(test_preds_heur)
# Out:
# (8431, 128688)

# %%
val_pred_df.to_csv("/content/drive/MyDrive/Crossroads/predictions/LGB_v1.0_val_sub_5.csv", index=False)

# %%
test_pred_df.to_csv("/content/drive/MyDrive/Crossroads/predictions/LGB_v1.0_test_sub_5.csv", index=False)
